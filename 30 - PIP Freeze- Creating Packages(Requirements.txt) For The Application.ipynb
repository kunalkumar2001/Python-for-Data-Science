# %% [markdown]
# # PIP Freeze- Creating Packages(Requirements.txt) For The Application

# %% [markdown]
# - pip freeze lists **all installed Python packages** in your current environment along with their **exact versions**.This is used to recreate the same environment on another machine.

# %%
# !pip freeze >requirements.txt
