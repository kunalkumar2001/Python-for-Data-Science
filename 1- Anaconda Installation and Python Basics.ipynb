# %% [markdown]
# # Basic of Python
#
# In this chapterwe will discuss about
#    - Various Datatypes in python
#    - Variable
#    - Variables Assignment
#    - Print Formatting

# %% [markdown]
# ## Various Datatypes in Python

# %% [markdown]
# ### Numbers

# %%
1+1
# Out:
# 2

# %%
5*20
# Out:
# 100

# %%
10/2
# Out:
# 5.0

# %%
10%2
# Out:
# 0

# %%
9%2
# Out:
# 1

# %%
9//2
# Out:
# 4

# %%
#check the Datatypes

# %%
type(1)
# Out:
# int

# %%
type(1.5)
# Out:
# float

# %%
z = 3 + 4j

# %%
type(z)
# Out:
# complex

# %%
z.real
# Out:
# 3.0

# %%
z.imag
# Out:
# 4.0

# %%
z.conjugate()
# Out:
# (3-4j)

# %%
z
# Out:
# (3+4j)

# %%
type(True)
# Out:
# bool

# %% [markdown]
# ### Strings

# %%
"Hello Kunal"
# Out:
# 'Hello Kunal'

# %%
type("Hello Kunal")
# Out:
# str

# %% [markdown]
# ### Variable Assignment

# %%
# Syntax
# Var_Name = values

a=10

# %%
type(a)
# Out:
# int

# %%
a = "Hello"

# %%
type(a)
# Out:
# str

# %%
# Mathematical Operation with Variable Assignment

# %%
a=10
b=20

# %%
a+b
# Out:
# 30

# %%
a*b
# Out:
# 200

# %%
b/a
# Out:
# 2.0

# %%
b//a
# Out:
# 2

# %%
b%a
# Out:
# 0

# %%
## Varoius Ways of Printing

# %%
print("Hello")
# Out:
# Hello

# %%
first_name = "Kunal"
last_name = "Kumar"

# %%
print("My first name is {} and last name is {}".format(first_name, last_name))
# Out:
# My first name is Kunal and last name is Kumar

# %%
print("My first name is {first} and last name is {last}".format(first=first_name, last=last_name))
# Out:
# My first name is Kunal and last name is Kumar
