# %%
# !pip install Pypdf2
# Out:
# Collecting Pypdf2
#   Downloading pypdf2-3.0.1-py3-none-any.whl.metadata (6.8 kB)
# Downloading pypdf2-3.0.1-py3-none-any.whl (232 kB)
#    ---------------------------------------- 0.0/232.6 kB ? eta -:--:--
#    ----- --------------------------------- 30.7/232.6 kB 660.6 kB/s eta 0:00:01
#    ------------ -------------------------- 71.7/232.6 kB 991.0 kB/s eta 0:00:01
#    --------------------- ------------------ 122.9/232.6 kB 1.0 MB/s eta 0:00:01
#    -------------------------------------- - 225.3/232.6 kB 1.5 MB/s eta 0:00:01
#    ---------------------------------------- 232.6/232.6 kB 1.3 MB/s eta 0:00:00
# Installing collected packages: Pypdf2
# Successfully installed Pypdf2-3.0.1

# %%
# !pip install PyPDF2
# Out:
# Requirement already satisfied: PyPDF2 in c:\users\kunal\anaconda3\lib\site-packages (3.0.1)

# %%
from PyPDF2 import PdfReader, PdfWriter

# %%
##open the current pdf file
file_pdf = PdfReader("pdf-sample_0.pdf")
##object for pdf writer
out_pdf = PdfWriter()

# %%
file_pdf

# %%
for i in range (len(file_pdf.pages)):
    page_details = file_pdf.pages[i]
    ### Add to output page
    out_pdf.add_page(page_details)

# %%
password = "Kunal@1234"

out_pdf.encrypt(password)

# %%
with open("lockpdf.pdf","wb") as filename:
    out_pdf.write(filename)
