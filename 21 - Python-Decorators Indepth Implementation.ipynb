# %%
def welcome():
    return "Welcome to Krish Naik Youtube Channel"

# %%
wel =welcome()
del welcome

# %%
wel
# Out:
# 'Welcome to Krish Naik Youtube Channel'

# %%
welcome()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 welcome()
#
# NameError: name 'welcome' is not defined

# %%
def main_message():
    msg = "Hello Everyone"
    def sub_message_class():
        print(msg)
        print("Welcome to Kunal Github Profile")
        print("Thank You")
        
    return sub_message_class()

# %%
main_message()
# Out:
# Hello Everyone
# Welcome to Kunal Github Profile
# Thank You

# %%
def main_message(msg):
    def sub_message_class():
        print(msg)
        print("Welcome to Kunal Github Profile")
        print("Thank You")
        
    return sub_message_class()

# %%
main_message("Hello Everyone")
# Out:
# Hello Everyone
# Welcome to Kunal Github Profile
# Thank You

# %%
def main_message(func):
    def sub_message_class():
        print("Welcome to Kunal Github Profile")
        func
        print("Thank You")
        
    return sub_message_class()

# %%
main_message(print)
# Out:
# Welcome to Kunal Github Profile
# Thank You

# %%
def main_message(func):
    def sub_message_class():
        func("Hello Everyone")
        print("Welcome to Kunal Github Profile")
        print("Thank You")
        
    return sub_message_class()

# %%
main_message(print)
# Out:
# Hello Everyone
# Welcome to Kunal Github Profile
# Thank You

# %%
def main_message(func):
    def sub_message_class():
        print("Welcome to Kunal Github Profile")
        print(func([1,2,3,4,5,6]))
        print("Thank You")
        
    return sub_message_class()

# %%
main_message(len)
# Out:
# Welcome to Kunal Github Profile
# 6
# Thank You

# %%
def main_message(func):
    def sub_message_class():
        print("Welcome to Kunal Github Profile")
        func()
        print("Thank You")
        
    return sub_message_class()

# %%
def github():
    print("Fork my github")

# %%
main_message(github)
# Out:
# Welcome to Kunal Github Profile
# Fork my github
# Thank You

# %%
@main_message
def github():
    print("Fork my github")
# Out:
# Welcome to Kunal Github Profile
# Fork my github
# Thank You
