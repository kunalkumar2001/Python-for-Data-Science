# %% [markdown]
# # =, copy(), and deepcopy()

# %%
lst1 = [1,2,3,4]
lst2 = lst1

# %%
lst2
# Out:
# [1, 2, 3, 4]

# %%
lst1
# Out:
# [1, 2, 3, 4]

# %%
lst2[1]= 1000

# %%
lst2
# Out:
# [1, 1000, 3, 4]

# %%
lst1
# Out:
# [1, 1000, 3, 4]

# %% [markdown]
# ## cpoy() or shallow copy()

# %%
lst1 = [1,2,3,4]
lst2 = lst1.copy()

# %%
lst2
# Out:
# [1, 2, 3, 4]

# %%
lst2[2]=1000

# %%
lst2
# Out:
# [1, 2, 1000, 4]

# %%
lst1
# Out:
# [1, 2, 3, 4]

# %%
##shallow copy nested list
lst1 = [[1,2,3,4], [5,6,7,8]]
lst2 = lst1.copy()

# %%
lst1
# Out:
# [[1, 2, 3, 4], [5, 6, 7, 8]]

# %%
lst2
# Out:
# [[1, 2, 3, 4], [5, 6, 7, 8]]

# %%
lst1[1][2]
# Out:
# 7

# %%
lst1[1][2] = 100

# %%
lst1
# Out:
# [[1, 2, 3, 4], [5, 6, 100, 8]]

# %%
lst2
# Out:
# [[1, 2, 3, 4], [5, 6, 100, 8]]

# %%
lst2[1][3]=1000

# %%
lst2
# Out:
# [[1, 2, 3, 4], [5, 6, 100, 1000]]

# %%
lst1
# Out:
# [[1, 2, 3, 4], [5, 6, 100, 1000]]

# %%
lst1.append([2,4,6,8])

# %%
lst1
# Out:
# [[1, 2, 3, 4], [5, 6, 100, 1000], [2, 4, 6, 8]]

# %%
lst2
# Out:
# [[1, 2, 3, 4], [5, 6, 100, 1000]]

# %%
##Deep copy()

# %%
import copy
lst1 = [1,2,3,4]
lst2 = copy.deepcopy(lst1)

# %%
lst2
# Out:
# [1, 2, 3, 4]

# %%
lst2[1]=100

# %%
lst2
# Out:
# [1, 100, 3, 4]

# %%
lst1
# Out:
# [1, 2, 3, 4]

# %%
## In a normal list shallow==deep copy

# %%
lst1 = [[1,2,3,4],[5,6,7,8],[2,4,6,8]]
lst2 = copy.deepcopy(lst1)

# %%
lst1
# Out:
# [[1, 2, 3, 4], [5, 6, 7, 8], [2, 4, 6, 8]]

# %%
lst2
# Out:
# [[1, 2, 3, 4], [5, 6, 7, 8], [2, 4, 6, 8]]

# %%
lst2[2][3] = 100

# %%
lst2
# Out:
# [[1, 2, 3, 4], [5, 6, 7, 8], [2, 4, 6, 100]]

# %%
lst1
# Out:
# [[1, 2, 3, 4], [5, 6, 7, 8], [2, 4, 6, 8]]

# %%
lst1 = [[1,2,3,4],[5,6,7,8],[2,4,6,8]]
lst2 = lst1.copy()

# %%
lst1
# Out:
# [[1, 2, 3, 4], [5, 6, 7, 8], [2, 4, 6, 8]]

# %%
lst2
# Out:
# [[1, 2, 3, 4], [5, 6, 7, 8], [2, 4, 6, 8]]

# %%
lst2[2][3]=100

# %%
lst2
# Out:
# [[1, 2, 3, 4], [5, 6, 7, 8], [2, 4, 6, 100]]

# %%
lst1
# Out:
# [[1, 2, 3, 4], [5, 6, 7, 8], [2, 4, 6, 100]]
